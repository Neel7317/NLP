# %% [markdown]
# <a href="https://colab.research.google.com/github/Neel7317/NLP/blob/main/LLM_02_Embeddings%2C_Vector_Databases(chromadb)%2C_and_Search_using_LLM(GPT2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install faiss-cpu==1.7.4 chromadb==0.3.21
# Out:
# Collecting faiss-cpu==1.7.4
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 33.5 MB/s eta 0:00:00
# Collecting chromadb==0.3.21
#   Downloading chromadb-0.3.21-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.5.3)
# Collecting requests>=2.28 (from chromadb==0.3.21)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.10.11)
# Collecting hnswlib>=0.7 (from chromadb==0.3.21)
#   Downloading hnswlib-0.7.0.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clickhouse-connect>=0.5.7 (from chromadb==0.3.21)
#   Downloading clickhouse_connect-0.6.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (966 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 966.2/966.2 kB 28.7 MB/s eta 0:00:00
# Collecting sentence-transformers>=2.2.2 (from chromadb==0.3.21)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: duckdb>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (0.8.1)
# Collecting fastapi>=0.85.1 (from chromadb==0.3.21)
#   Downloading fastapi-0.100.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 5.3 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb==0.3.21)
#   Downloading uvicorn-0.23.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.22.4)
# Collecting posthog>=2.4.0 (from chromadb==0.3.21)
#   Downloading posthog-3.0.1-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2023.5.7)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (4.6.4)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (1.26.16)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2022.7.1)
# Collecting zstandard (from clickhouse-connect>=0.5.7->chromadb==0.3.21)
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 50.9 MB/s eta 0:00:00
# Collecting lz4 (from clickhouse-connect>=0.5.7->chromadb==0.3.21)
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.9 MB/s eta 0:00:00
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.85.1->chromadb==0.3.21)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.85.1->chromadb==0.3.21) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->chromadb==0.3.21) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.3.21) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.3.21)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.3.21)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.3.21) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.3.21) (3.4)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 68.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.21) (8.1.6)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.4 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 33.3 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.21) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 73.3 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.6 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (23.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb==0.3.21) (3.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.2->chromadb==0.3.21) (8.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb==0.3.21) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb==0.3.21) (1.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.3.0)
# Building wheels for collected packages: hnswlib, sentence-transformers
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.7.0-cp310-cp310-linux_x86_64.whl size=2201754 sha256=f2cbe374d35718e9b7fb4cd2f7f71ed71d0922a56cc7f105804719ed0dc903eb
#   Stored in directory: /root/.cache/pip/wheels/8a/ae/ec/235a682e0041fbaeee389843670581ec6c66872db856dfa9a4
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=122a672d577652db8d7ad0f72739579ae4590f987a748f9ba52b0af21343911f
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built hnswlib sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, monotonic, faiss-cpu, zstandard, websockets, uvloop, requests, python-dotenv, lz4, httptools, hnswlib, h11, backoff, watchfiles, uvicorn, starlette, posthog, huggingface-hub, clickhouse-connect, transformers, fastapi, sentence-transformers, chromadb
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# Successfully installed backoff-2.2.1 chromadb-0.3.21 clickhouse-connect-0.6.8 faiss-cpu-1.7.4 fastapi-0.100.0 h11-0.14.0 hnswlib-0.7.0 httptools-0.6.0 huggingface-hub-0.16.4 lz4-4.3.2 monotonic-1.6 posthog-3.0.1 python-dotenv-1.0.0 requests-2.31.0 safetensors-0.3.1 sentence-transformers-2.2.2 sentencepiece-0.1.99 starlette-0.27.0 tokenizers-0.13.3 transformers-4.31.0 uvicorn-0.23.1 uvloop-0.17.0 watchfiles-0.19.0 websockets-11.0.3 zstandard-0.21.0

# %%
import pandas as pd

pdf = pd.read_csv(f"/content/drive/MyDrive/labelled_newscatcher_dataset.csv", sep=";")
pdf["id"] = pdf.index
display(pdf)
# Out:
#                 topic                                               link  \
# 0             SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 1             SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...
# 2             SCIENCE  https://www.express.co.uk/news/science/1322607...
# 3             SCIENCE  https://www.ndtv.com/world-news/glaciers-could...
# 4             SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...
# ...               ...                                                ...
# 108769         NATION  https://www.vanguardngr.com/2020/08/pdp-govern...
# 108770       BUSINESS  https://www.patentlyapple.com/patently-apple/2...
# 108771         HEALTH  https://www.belfastlive.co.uk/news/health/coro...
# 108772  ENTERTAINMENT  https://www.thenews.com.pk/latest/696364-paul-...
# 108773         SPORTS  https://www.balls.ie/football/shane-duffy-brig...
#
#                    domain       published_date  \
# 0          eurekalert.org  2020-08-06 13:59:45
# 1                pulse.ng  2020-08-12 15:14:19
# 2           express.co.uk  2020-08-13 21:01:00
# 3                ndtv.com  2020-08-03 22:18:26
# 4               thesun.ie  2020-08-12 19:54:36
# ...                   ...                  ...
# 108769    vanguardngr.com  2020-08-08 02:40:00
# 108770  patentlyapple.com  2020-08-08 01:27:12
# 108771  belfastlive.co.uk  2020-08-12 17:01:00
# 108772     thenews.com.pk  2020-08-05 04:59:00
# 108773           balls.ie  2020-08-09 10:25:26
#
#                                                     title lang      id
# 0       A closer look at water-splitting's solar fuel ...   en       0
# 1       An irresistible scent makes locusts swarm, stu...   en       1
# 2       Artificial intelligence warning: AI will know ...   en       2
# 3        Glaciers Could Have Sculpted Mars Valleys: Study   en       3
# 4       Perseid meteor shower 2020: What time and how ...   en       4
# ...                                                   ...  ...     ...
# 108769  PDP governors’ forum urges security agencies t...   en  108769
# 108770  In Q2-20, Apple Dominated the Premium Smartpho...   en  108770
# 108771  Coronavirus Northern Ireland: Full breakdown s...   en  108771
# 108772  Paul McCartney details post-Beatles distress a...   en  108772
# 108773  Report: Talks Underway To Keep Shane Duffy In ...   en  108773
#
# [108774 rows x 7 columns]

# %%
from sentence_transformers import InputExample

pdf_subset = pdf.head(1000)

def example_create_fn(doc1: pd.Series) -> InputExample:
    """
    Helper function that outputs a sentence_transformer guid, label, and text
    """
    return InputExample(texts=[doc1])

faiss_train_examples = pdf_subset.apply(
    lambda x: example_create_fn(x["title"]), axis=1
).tolist()

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(
    "all-MiniLM-L6-v2"
)  # Use a pre-cached model
faiss_title_embedding = model.encode(pdf_subset.title.values.tolist())
len(faiss_title_embedding), len(faiss_title_embedding[0])
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# (1000, 384)

# %%
# Step 3: Saving embedding vectors to FAISS index
import numpy as np
import faiss

pdf_to_index = pdf_subset.set_index(["id"], drop=False)
id_index = np.array(pdf_to_index.id.values).flatten().astype("int")

content_encoded_normalized = faiss_title_embedding.copy()
faiss.normalize_L2(content_encoded_normalized)

# Index1DMap translates search results to IDs: https://faiss.ai/cpp_api/file/IndexIDMap_8h.html#_CPPv4I0EN5faiss18IndexIDMapTemplateE
# The IndexFlatIP below builds index
index_content = faiss.IndexIDMap(faiss.IndexFlatIP(len(faiss_title_embedding[0])))
index_content.add_with_ids(content_encoded_normalized, id_index)

# %%
## Step 4: Search for relevant documents
def search_content(query, pdf_to_index, k=3):
    query_vector = model.encode([query])
    faiss.normalize_L2(query_vector)

    # We set k to limit the number of vectors we want to return
    top_k = index_content.search(query_vector, k)
    ids = top_k[1][0].tolist()
    similarities = top_k[0][0].tolist()
    results = pdf_to_index.loc[ids]
    results["similarities"] = similarities
    return results

# %%
# MAGIC Tada! Now you can query for similar content! Notice that you did not have to configure any database networks beforehand nor pass in any credentials. FAISS works locally with your code.

# COMMAND ----------

display(search_content("animal", pdf_to_index))
# Out:
#           topic                                               link  \
# id
# 176  TECHNOLOGY  https://www.pushsquare.com/news/2020/08/random...
# 975      HEALTH  https://www.news-medical.net/news/20200813/Res...
# 99   TECHNOLOGY  https://www.gematsu.com/2020/08/ghostwire-toky...
#
#                domain       published_date  \
# id
# 176    pushsquare.com  2020-08-03 16:30:00
# 975  news-medical.net  2020-08-13 05:18:00
# 99        gematsu.com  2020-08-07 16:43:13
#
#                                                  title lang   id  similarities
# id
# 176  Random: You Can Pick Up and Pet Cats in Assass...   en  176      0.391902
# 975  Researchers explore social behavior of animals...   en  975      0.376784
# 99               Ghostwire: Tokyo confirms dog petting   en   99      0.344058

# %%
# MAGIC Up until now, we haven't done the last step of conducting Q/A with a language model yet. We are going to demonstrate this with Chroma, a vector database.

# %%
import chromadb
from chromadb.config import Settings

chroma_client = chromadb.Client()

# chroma_client = chromadb.Client(
#     Settings(
#         chroma_db_impl="duckdb+parquet",
#         persist_directory=DA.paths.user_db,  # this is an optional argument. If you don't supply this, the data will be ephemeral
#     )
# )
# Out:
# WARNING:chromadb:Using embedded DuckDB without persistence: data will be transient

# %%
collection_name = "my_news"

# If you have created the collection before, you need to delete the collection first
if len(chroma_client.list_collections()) > 0 and collection_name in [chroma_client.list_collections()[0].name]:
    chroma_client.delete_collection(name=collection_name)

print(f"Creating collection: '{collection_name}'")
collection = chroma_client.create_collection(name=collection_name)
# Out:
# WARNING:chromadb.api.models.Collection:No embedding_function provided, using default embedding function: SentenceTransformerEmbeddingFunction
# Creating collection: 'my_news'

# %%
display(pdf_subset)
# Out:
#           topic                                               link  \
# 0       SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 1       SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...
# 2       SCIENCE  https://www.express.co.uk/news/science/1322607...
# 3       SCIENCE  https://www.ndtv.com/world-news/glaciers-could...
# 4       SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...
# ..          ...                                                ...
# 995  TECHNOLOGY  https://www.androidcentral.com/mate-40-will-be...
# 996     SCIENCE  https://www.cnn.com/2020/08/17/africa/stone-ag...
# 997      HEALTH  https://www.tenterfieldstar.com.au/story/68776...
# 998      HEALTH  https://news.sky.com/story/coronavirus-trials-...
# 999      HEALTH  https://www.techexplorist.com/study-demonstrat...
#
#                      domain       published_date  \
# 0            eurekalert.org  2020-08-06 13:59:45
# 1                  pulse.ng  2020-08-12 15:14:19
# 2             express.co.uk  2020-08-13 21:01:00
# 3                  ndtv.com  2020-08-03 22:18:26
# 4                 thesun.ie  2020-08-12 19:54:36
# ..                      ...                  ...
# 995      androidcentral.com  2020-08-07 17:12:33
# 996                 cnn.com  2020-08-17 17:10:00
# 997  tenterfieldstar.com.au  2020-08-13 03:26:06
# 998            news.sky.com  2020-08-13 13:22:58
# 999       techexplorist.com  2020-08-10 07:47:00
#
#                                                  title lang   id
# 0    A closer look at water-splitting's solar fuel ...   en    0
# 1    An irresistible scent makes locusts swarm, stu...   en    1
# 2    Artificial intelligence warning: AI will know ...   en    2
# 3     Glaciers Could Have Sculpted Mars Valleys: Study   en    3
# 4    Perseid meteor shower 2020: What time and how ...   en    4
# ..                                                 ...  ...  ...
# 995  The Mate 40 will be the last Huawei phone with...   en  995
# 996  Early humans knew how to make comfy, pest-free...   en  996
# 997           Regional Vic set for virus testing blitz   en  997
# 998  Coronavirus: Trials of second contact-tracing ...   en  998
# 999  The study demonstrates new treatment for prion...   en  999
#
# [1000 rows x 7 columns]

# %% [markdown]
# # Each document must have a unique `id` associated with it and it is up to you to check that there are no duplicate ids.
#
# # Adding data to collection will take some time to run, especially when there is a lot of data. In the cell below, we intentionally write only a subset of data to the collection to speed things up.

# %%
collection.add(
    documents=pdf_subset["title"][:100].tolist(),
    metadatas=[{"topic": topic} for topic in pdf_subset["topic"][:100].tolist()],
    ids=[f"id{x}" for x in range(100)],
)

# %%
#  ### Step 2: Query for 10 relevant documents on "space"

# We will return 10 most relevant documents. You can think of `10` as 10 nearest neighbors. You can also change the number of results returned as well.

# COMMAND ----------

import json

results = collection.query(query_texts=["space"], n_results=10)

print(json.dumps(results, indent=4))
# Out:
# {
#     "ids": [
#         [
#             "id72",
#             "id7",
#             "id30",
#             "id26",
#             "id23",
#             "id76",
#             "id69",
#             "id47",
#             "id75",
#             "id52"
#         ]
#     ],
#     "embeddings": null,
#     "documents": [
#         [
#             "Beck teams up with NASA and AI for 'Hyperspace' visual album experience",
#             "Orbital space tourism set for rebirth in 2021",
#             "NASA drops \"insensitive\" nicknames for cosmic objects",
#             "\u2018It came alive:\u2019 NASA astronauts describe experiencing splashdown in SpaceX Dragon",
#             "Hubble Uses Moon As \u201cMirror\u201d to Study Earth\u2019s Atmosphere \u2013 Proxy in Search of Potentially Habitable Planets Around Other Stars",
#             "Australia's small yet crucial part in the mission to find life on Mars",
#             "NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico",
#             "NASA\u2019s InSight lander shows what\u2019s beneath Mars\u2019 surface",
#             "Alien base on Mercury: ET hunters claim to find huge UFO",
#             "SpaceX Crew-1 mission with NASA, first fully operational crewed mission to space to launch in October"
#         ]
#     ],
#     "metadatas": [
#         [
#             {
#                 "topic": "TECHNOLOGY"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             }
#         ]
#     ],
#     "distances": [
#         [
#             1.2250354290008545,
#             1.3089773654937744,
#             1.391038417816162,
#             1.4064621925354004,
#             1.4391300678253174,
#             1.4898791313171387,
#             1.5728247165679932,
#             1.5835301876068115,
#             1.5864628553390503,
#             1.5984288454055786
#         ]
#     ]
# }

# %%
# Bonus: Add filter statement
collection.query(query_texts=["space"], where={"topic": "SCIENCE"}, n_results=10)
# Out:
# {'ids': [['id7',
#    'id30',
#    'id26',
#    'id23',
#    'id76',
#    'id69',
#    'id47',
#    'id75',
#    'id52',
#    'id35']],
#  'embeddings': None,
#  'documents': [['Orbital space tourism set for rebirth in 2021',
#    'NASA drops "insensitive" nicknames for cosmic objects',
#    '‘It came alive:’ NASA astronauts describe experiencing splashdown in SpaceX Dragon',
#    'Hubble Uses Moon As “Mirror” to Study Earth’s Atmosphere – Proxy in Search of Potentially Habitable Planets Around Other Stars',
#    "Australia's small yet crucial part in the mission to find life on Mars",
#    'NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico',
#    'NASA’s InSight lander shows what’s beneath Mars’ surface',
#    'Alien base on Mercury: ET hunters claim to find huge UFO',
#    'SpaceX Crew-1 mission with NASA, first fully operational crewed mission to space to launch in October',
#    'Man posts mind-blowing TikTok from highest point in Canada to disprove Flat Earth theory']],
#  'metadatas': [[{'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'}]],
#  'distances': [[1.3089773654937744,
#    1.391038417816162,
#    1.4064621925354004,
#    1.4391300678253174,
#    1.4898791313171387,
#    1.5728247165679932,
#    1.5835301876068115,
#    1.5864628553390503,
#    1.5984288454055786,
#    1.6189424991607666]]}

# %%
# Bonus: Update data in a collection
collection.delete(ids=["id0"])
# Out:
# [UUID('0d8b670e-0c55-4b7f-83c9-4b9aaaae22b1')]

# %%
collection.get(ids=["id0"])
# Out:
# {'ids': [], 'embeddings': None, 'documents': [], 'metadatas': []}

# %%
collection.get(ids=["id2"])
# Out:
# {'ids': ['id2'],
#  'embeddings': None,
#  'documents': ['Artificial intelligence warning: AI will know us better than we know ourselves'],
#  'metadatas': [{'topic': 'SCIENCE'}]}

# %%
collection.update(
    ids=["id2"],
    metadatas=[{"topic": "TECHNOLOGY"}],
)

# %%
collection.get(ids=["id2"])
# Out:
# {'ids': ['id2'],
#  'embeddings': None,
#  'documents': ['Artificial intelligence warning: AI will know us better than we know ourselves'],
#  'metadatas': [{'topic': 'TECHNOLOGY'}]}

# %%
# Prompt engineering for question answering

# %%
# We first need to pick a `text-generation` model. Below, we use a Hugging Face model.
# You can also use OpenAI as well, but you will need to get an Open AI token and [pay based on the number of tokens](https://openai.com/pricing).


from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
lm_model = AutoModelForCausalLM.from_pretrained(model_id)

pipe = pipeline(
    "text-generation",
    model=lm_model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    device_map="auto",
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
question = "What's the latest news on space development?"
context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
prompt_template = f"Relevant context: {context}\n\n The user's question: {question}"

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Relevant context: #Beck teams up with NASA and AI for 'Hyperspace' visual album experience #Orbital space tourism set for rebirth in 2021 #NASA drops "insensitive" nicknames for cosmic objects #‘It came alive:’ NASA astronauts describe experiencing splashdown in SpaceX Dragon #Hubble Uses Moon As “Mirror” to Study Earth’s Atmosphere – Proxy in Search of Potentially Habitable Planets Around Other Stars #Australia's small yet crucial part in the mission to find life on Mars #NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico #NASA’s InSight lander shows what’s beneath Mars’ surface #Alien base on Mercury: ET hunters claim to find huge UFO #SpaceX Crew-1 mission with NASA, first fully operational crewed mission to space to launch in October
#
#  The user's question: What's the latest news on space development?
#
#
# Why in the world would a Space Exploration Engineer ever be a space enthusiast? I think the Space Program is very much like a business - so it has a very big need. But I think the Space Program is really at the heart of the business. The Commercial Crew Program is very critical to space development now. And in the Commercial Crew Program we got much more space development than in the past, more commercial people than in any time since the Industrial Revolution, and a lot of commercial people here were in the past space explorers. The reason for that is for both commercial and commercial operations. You only see commercial people at NASA, you see commercial people on their missions to Mars. So when you look at NASA, every commercial person is someone who really makes a difference. They help with the exploration of the universe with their astronauts.
#
#
# Space Exploration Engineers are really involved with the space program. They work through the space program so they can tell how NASA works and what they can learn from it. It's not as if they're a military man-peasant for space exploration. They make sure all the instruments they are doing and every step they take and every mission they undertake to help you go beyond all those things that are available, and go beyond, and really, really make space go beyond what NASA is.
#
# What's also remarkable is that the Commercial Crew Program is going out of business today. And NASA is trying to revive them, but they're a very different organization here than they are in the past couple of years, and they're no longer competitive because they've been in business for quite a long time. The Commercial Crew Program is really what brings us together here at NASA. A lot of the things that have happened so far, the things that we've been doing in the past are a bit dated. Today's space industry is still very new. But the Commercial Crew Program is a very good example of how we can get out of the way of what's going on.
#
#
# And I believe, as a long time Space Marine, in our view, NASA is very much a good partner because we're a part of the space industry. We have a lot of relationships here at NASA, especially with commercial investors and I believe that. Now that the commercial market isn't such a big problem, I think NASA really believes it will be a great partner because we're not involved in a lot of the things that are currently happening here at NASA and that's really part of our success. We don't talk much about our
